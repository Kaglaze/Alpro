# %% [markdown]
# # Materi Perkuliahan

# %% [markdown]
# Daftar isi materi Alpro selama satu semester ini:

# %% [markdown]
# ## 1.Materi Pertemuan Pertama

# %% [markdown]
# [1.1 Pengenalan Algoritma Pemrograman](Intro.ipynb)

# %% [markdown]
# [1.2 Data Type](Data.ipynb)

# %% [markdown]
# [1.3 Variabel](Variable.ipynb)

# %% [markdown]
# [1.4 Operator](Operators.ipynb)

# %% [markdown]
# ## 2.Materi Pertemuan Kedua

# %% [markdown]
# [2.1 Algoritma](Algoritma.ipynb)

# %% [markdown]
# [2.2 Jenis Algoritma](JenisAlgoritma.ipynb)

# %% [markdown]
# [2.3 Flowchart](Flowchart.ipynb)

# %% [markdown]
# ## 3.Materi Pertemuan Ketiga

# %% [markdown]
# [3.1 Loop](Loop.ipynb)

# %% [markdown]
# ## 4.Materi Pertemuan Keempat

# %% [markdown]
# [4.1 String](String.ipynb)

# %% [markdown]
# ## 5.Materi Kelima

# %% [markdown]
# [5.1 List](List.ipynb)

# %% [markdown]
# [5.2 List Comprehension](ListComprehension.ipynb)

# %% [markdown]
# ## 6.Materi Keenam

# %% [markdown]
# [6.1 Tuple](Tuples.ipynb)

# %% [markdown]
# ## 7.Materi Ketujuh

# %% [markdown]
# [7.1 Fungsi](Fungsi.ipynb)

# %% [markdown]
# [7.2 Fungsi Rekursif](Fungsirekursif.ipynb)

# %% [markdown]
# ## 8.Materi Kedelapan

# %% [markdown]
# [8.1 Dictionary](Dictionary.ipynb)
