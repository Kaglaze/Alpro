# %% [markdown]
# ## GeeksForGeeks

# %% [raw]
# Question 1
# What is the output of the following program
# tup = (1, 2, 3, 4)
# tup.append( (5, 6, 7) )
# print(len(tup))
#
# Error

# %% [raw]
# Question 2
# What is the output of the following program?
# tup = {}
# tup[(1,2,4)] = 8
# tup[(4,2,1)] = 10
# tup[(1,2)] = 12
# sum1 = 0
# for k in tup:
# 	sum1 += tup[k]
# print(len(tup) + sum1)
#
# 33

# %% [raw]
# Question 3
# What is the output of the following program?
# tup1 = (1, 2, 4, 3)
# tup2 = (1, 2, 3, 4)
# print(tup1 < tup2)
#
# False

# %% [raw]
# Question 4
# What is the output of the following program?
# tup = (1, 2, 3)
# print(2 * tup)
#
# (1, 2, 3, 1, 2, 3)

# %% [raw]
# Question 5
# What is the output of the following program?
# tup=("Check")*3
# print(tup)
#
# CheckCheckCheck

# %% [raw]
# Question 6
# What is the output of the following program?
# s = 'geeks'
# a, b, c, d, e = s
# b = c = '*'
# s = (a, b, c, d, e)
# print(s)
#
# (‘g’, ‘*’, ‘*’, ‘k’, ‘s’)

# %% [raw]
# Question 7
# What is the output of the following program?
# tup = (2e-04, True, False, 8, 1.001, True)
# val = 0
# for x in tup:
#     val += int(x)
# print(val)
#
#
# 11

# %% [raw]
# Question 8
# What is the output of the following program?
# li = [3, 1, 2, 4]
# tup = ('A', 'b', 'c', 'd')
# li.sort()
# counter = 0
# for x in tup:
# 	li[counter] += int(x)
# 	counter += 1
# 	break
# print(li)
#
# ValueError

# %% [raw]
# Question 9
# What is the output of the following program?
# li = [2e-04, 'a', False, 87]
# tup = (6.22, 'boy', True, 554)
# for i in range(len(li)):
# 	if li[i]:
# 		li[i] = li[i] + tup[i]
# 	else:
# 		tup[i] = li[i] + li[i]
# 		break
#
# TypeError

# %% [raw]
# Question 10
# What is the output of the following program?
# import sys
# tup = tuple()
# print(sys.getsizeof(tup), end = " ")
# tup = (1, 2)
# print(sys.getsizeof(tup), end = " ")
# tup = (1, 3, (4, 5))
# print(sys.getsizeof(tup), end = " ")
# tup = (1, 2, 3, 4, 5, [3, 4], 'p', '8', 9.777, (1, 3))
# print(sys.getsizeof(tup))
#
# 48 64 72 128

# %% [raw]
# Question 11
# What is the output of the following program?
# tup1 = (1)
# tup2 = (3, 4)
# tup1 += 5
# print(tup1)
#
# 6

# %% [markdown]
# ## W3SHCOOLS

# %%
# 1.Which one of these is a tuple?
thistuple = ('apple', 'banana', 'cherry')

# %%
# 2.Use the correct syntax to print the number of items in the fruits tuple.
fruits = ("apple", "banana", "cherry")
print(len(fruits))
# Out:
# 3

# %%
# 3.True or False.
#Tuple items cannot be removed after the tuple has been created.
True
# Out:
# True

# %% [markdown]
# #### Access Tuple

# %%
# 1.You can access tuple items by referring to the index number, but what is the index number of the first item?
# 0

# %%
# 2.Use the correct syntax to print the first item in the fruits tuple.
fruits = ("apple", "banana", "cherry")
print(fruits[0])
# Out:
# apple

# %%
# 3.Use negative indexing to print the last item in the tuple.
fruits = ("apple", "banana", "cherry")
print(fruits[-1])
# Out:
# cherry

# %%
# 4.Use a range of indexes to print the third, fourth, and fifth item in the tuple.
fruits = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(fruits[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %% [markdown]
# #### Update Tuple

# %% [markdown]
# 1.You cannot change the items of a tuple, but there are workarounds. Which of the following suggestion will work?
#
# Convert tuple into a list, change item, convert back into a tuple.

# %% [markdown]
# 2.Which is a correct syntax to delete a tuple?
#
# del mytuple

# %% [markdown]
# 3.True or False. You are allowed to add a tuple to an existing tuple.
#
# True

# %% [markdown]
# ### Python Unpack Tuples

# %%
#1.Consider the following code:
fruits = ('apple', 'banana', 'cherry')
(x, y, z) = fruits
print(y)
#What will be the value of y?
# Out:
# banana

# %%
#2.Consider the following code:
fruits = ('apple', 'banana', 'cherry')
(x, *y) = fruits
print(y)
#What will be the value of y?
# Out:
# ['banana', 'cherry']

# %%
#3.Consider the following code:
fruits = ('apple', 'banana', 'cherry', 'mango')
(x, *y, z) = fruits
print(y)
#What will be the value of y?
# Out:
# ['banana', 'cherry']

# %% [markdown]
# ### Python Loop Tuples

# %% [markdown]
# 1.What is a correct syntax for looping through the items of a tuple?
#
# for x in ('apple', 'banana', 'cherry'):
#
#   print(x)

# %%
#2.Insert the missing part of the while loop below to loop through the items of a tuple.
mytuple = ('apple', 'banana', 'cherry')
i = 0
while i < len(mytuple):
  print(mytuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
#3.Insert the missing part of the for loop below to loop through the items of a tuple by using the range function to loop through the tuple's index numbers
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ### Python Join Tuples

# %% [markdown]
# 1.What is a correct syntax for joining tuple1 and tuple2 into tuple3?
#
# tuple3 = tuple1 + tuple2

# %% [markdown]
# 2.What is a legal way to turn this tuple: (1,2,3) into this tuple:(1,2,3,1,2,3)?
#
# tuple1 = (1,2,3)
#
# tuple1 = tuple1 * 2

# %%
#3.Consider the following code:
tuple1 = ('a', 'b' , 'c')
tuple2 = (1, 2, 3)
tuple3 = tuple2 + tuple1
#What will be the value of tuple3?
print(tuple3)
# Out:
# (1, 2, 3, 'a', 'b', 'c')

# %% [markdown]
# # quiz

# %% [markdown]
# 1. Buat sebuah tuple berisi angka 1–5.

# %%
tup = (1,2,3,4,5)
print(tup)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# 2. Dari t = (10,20,30,40,50), cetak elemen ketiga.

# %%
t = (10,20,30,40,50)
print(t[2])
# Out:
# 30

# %% [markdown]
# 3. Buat tuple yang berisi nama dan umur Anda.

# %%
tup = ("Moch. Habdulbar", 18)
print(tup)
# Out:
# ('Moch. Habdulbar', 18)

# %% [markdown]
# 4. Dari t = (5,10,15,20), tampilkan panjang tuple.

# %%
t = (5,10,15,20)
print(len(t))
# Out:
# 4

# %% [markdown]
# 5. Cek apakah angka 15 terdapat dalam tuple t = (5,10,15,20).

# %%
t = (5,10,15,20)
if 15 in t:
    print("15 terdapat dalam t")
else:
    print("Tidak dalam t")
# Out:
# 15 terdapat dalam t

# %% [markdown]
# 6. Dari t = (2,4,6,8,10), buat tuple baru berisi angka > 5.

# %%
t = (2,4,6,8,10)
newtuple = tuple(x for x in t if x > 5)
print(newtuple)
# Out:
# (6, 8, 10)

# %% [markdown]
# 7. Gabungkan a = (1,2,3) dan b = (4,5,6).

# %%
a = (1,2,3)
b = (4,5,6)
c = a + b
print(c)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# 8. Tup t = (9,8,7,6,3,3) Dari tuple berikut, hitung berapa kali angka 3 muncul

# %%
t = (9,8,7,6,3,3) 
a = 0
for i in t:
    if i == 3:
        a += 1
print(f"3 muncul sebanyak {a}")
# Out:
# 3 muncul sebanyak 2

# %% [markdown]
# 9. Dari t = ('apple','banana','cherry','date'), ambil dua elemen terakhir.

# %%
t = ('apple','banana','cherry','date')
print(t[2:])
# Out:
# ('cherry', 'date')

# %% [markdown]
# 10. Dari t = (1,2,3,4,5), Tampilkan indeks dari elemen bernilai 3

# %%
t = (1,2,3,4,5)
print(t[2])
# Out:
# 3
